# %%
import seaborn as sns
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df=sns.load_dataset('titanic')
sns.barplot(x="sex",y="age",data=df)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df=sns.load_dataset('titanic')
sns.barplot(x="sex",y="age",data=df,palette={"male":"red","female":"orange"})
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df=sns.load_dataset("titanic")
sns.barplot(x="sex",y="age",data=df,palette={"male":"white","female":"pink"})
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df["survived"].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
import seaborn as sns
df=sns.load_dataset('titanic')
df["survived"].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
cond1=df["survived"]==0
cond2=df["survived"]==1
df[cond1]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[cond2]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
a=[0,1]
b=df["survived"].isin(a)
df1=df[b]
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
cond1=df["sex"]=="male"
cond2=df["sex"]=="female"
df1=df.loc[cond1|cond2]
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df=sns.load_dataset('titanic')
df=sns.countplot(x="survived",data=df)

# %%
import seaborn as sns
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df=sns.load_dataset('titanic')
sns.barplot(x="class",y="survived",data=df)
# Out:
# <Axes: xlabel='class', ylabel='survived'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df=sns.countplot(x="survived",hue="adult_male",data=df,palette={False:"red",True:"orange"})

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df=sns.load_dataset('titanic')
result=df.pivot_table("survived",index="sex",columns="class")
print(result)
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
import matplotlib.pyplot as plt
import seaborn as sns
result=df.pivot_table("survived",index="sex",columns="class")
print(result)
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
import seaborn as sns
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
result=df.pivot_table("survived",index="who",columns="sex")
print(result)
# Out:
# sex      female      male
# who
# child  0.651163  0.525000
# man         NaN  0.163873
# woman  0.756458       NaN

# %%
import matplotlib.pyplot as plt
import seaborn as sns
result=df.pivot_table("survived",index="age",columns="sex")
print(result.to_string())
# Out:
# sex      female      male
# age
# 0.42        NaN  1.000000
# 0.67        NaN  1.000000
# 0.75   1.000000       NaN
# 0.83        NaN  1.000000
# 0.92        NaN  1.000000
# 1.00   1.000000  0.600000
# 2.00   0.333333  0.250000
# 3.00   0.500000  1.000000
# 4.00   1.000000  0.400000
# 5.00   1.000000       NaN
# 6.00   0.500000  1.000000
# 7.00   1.000000  0.000000
# 8.00   0.500000  0.500000
# 9.00   0.000000  0.500000
# 10.00  0.000000  0.000000
# 11.00  0.000000  0.333333
# 12.00       NaN  1.000000
# 13.00  1.000000       NaN
# 14.00  0.750000  0.000000
# 14.50  0.000000       NaN
# 15.00  1.000000  0.000000
# 16.00  0.833333  0.090909
# 17.00  0.833333  0.142857
# 18.00  0.615385  0.076923
# 19.00  1.000000  0.111111
# 20.00  0.000000  0.230769
# 20.50       NaN  0.000000
# 21.00  0.571429  0.058824
# 22.00  0.833333  0.066667
# 23.00  0.800000  0.100000
# 23.50       NaN  0.000000
# 24.00  0.875000  0.071429
# 24.50       NaN  0.000000
# 25.00  0.400000  0.222222
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
ages=pd.cut(df['age'],[0,20,80])
result=df.pivot_table("survived",["sex",ages],columns="class")
print(result)
# Out:
# class               First    Second     Third
# sex    age
# female (0, 20]   0.928571  1.000000  0.510638
#        (20, 80]  0.971831  0.896552  0.418182
# male   (0, 20]   0.571429  0.526316  0.197368
#        (20, 80]  0.382979  0.062500  0.129944

# %%
ages=pd.cut(df["age"],[0,25,90])
result=df.pivot_table("survived",["sex",ages],columns="class")
print(result)
# Out:
# class               First    Second     Third
# sex    age
# female (0, 25]   0.928571  0.965517  0.507692
#        (25, 90]  0.982456  0.888889  0.378378
# male   (0, 25]   0.500000  0.277778  0.155039
#        (25, 90]  0.379310  0.079365  0.145161

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(df["age"],kde=False)
# Out:
# <Axes: xlabel='age'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.countplot(x="survived",data=df)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.barplot(x="sex",y="age",data=df)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.barplot(x="survived",y="sex",data=df)
# Out:
# <Axes: xlabel='survived', ylabel='sex'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.barplot(x="sex",y="age",data=df)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.barplot(x="sex",y="age",hue="who",data=df,palette={"man":"yellow","woman":"orange","child":"pink"})
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.barplot(x="survived",y="sex",data=df)
# Out:
# <Axes: xlabel='survived', ylabel='sex'>

# %%
sns.countplot(x="survived",data=df)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.barplot(x="class",y="survived",data=df)
# Out:
# <Axes: xlabel='class', ylabel='survived'>

# %%
sns.barplot(x="pclass",y="survived",data=df)
# Out:
# <Axes: xlabel='pclass', ylabel='survived'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
result=df.pivot_table("survived",index="sex",columns="class")
print(result)
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
result=df.pivot_table("survived",index="sex",columns="who")
result
# Out:
# who        child       man     woman
# sex
# female  0.651163       NaN  0.756458
# male    0.525000  0.163873       NaN

# %%
ages=pd.cut(df["age"],[0,30,80])
result=df.pivot_table("survived",["sex",ages],columns="class")
print(result)
# Out:
# class               First    Second     Third
# sex    age
# female (0, 30]   0.942857  0.931818  0.506329
#        (30, 80]  0.980000  0.900000  0.304348
# male   (0, 30]   0.500000  0.192308  0.167630
#        (30, 80]  0.360000  0.106383  0.112500

# %%
sns.distplot(df['fare'],kde=False)
# Out:
# <Axes: xlabel='fare'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.barplot(x="sex",y="age",data=df,palette={"male":"orange","female":"yellow"})
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.barplot(y="survived",hue="sex",x="class",data=df,palette={"male":"orange","female":"red"})
# Out:
# <Axes: xlabel='class', ylabel='survived'>

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.barplot(y="survived",x="class",data=df)
# Out:
# <Axes: xlabel='class', ylabel='survived'>

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.barplot(x="who",y="survived",data=df)
# Out:
# <Axes: xlabel='who', ylabel='survived'>

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.countplot(x="sex",hue="survived",data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
result=df.pivot_table("survived",index="sex",columns="class")
print(result)
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
result=df.pivot_table("pclass",index="sex",columns="class")
print(result)
# Out:
# class   First  Second  Third
# sex
# female    1.0     2.0    3.0
# male      1.0     2.0    3.0

# %%
ages=pd.cut(df["age"],[0,25,80])
result=df.pivot_table("survived",[ages],columns="class")
print(result)
# Out:
# class        First    Second     Third
# age
# (0, 25]   0.785714  0.584615  0.273196
# (25, 80]  0.618056  0.416667  0.198758

# %%
ages=pd.cut(df["age"],[0,30,90])
result=df.pivot_table("survived",[ages],columns="class")
print(result)
# Out:
# class        First    Second    Third
# age
# (0, 30]   0.754098  0.531250  0.27381
# (30, 90]  0.608000  0.415584  0.15534

# %%
sns.distplot(df["fare"],kde=False)
# Out:
# <Axes: xlabel='fare'>
